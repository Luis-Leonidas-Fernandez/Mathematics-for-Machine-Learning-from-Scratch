# %%
import numpy as np
import matplotlib.pyplot as plt

vector = np.array([1,2,3])
print("vector:",vector)
print("vector shape:", vector.shape)

#crear una matriz
matrix = np.array([[1,2], [3,4]])
print("\nMatriz:")
print(matrix)
print("matriz shape:", matrix.shape)
# Out:
# vector: [1 2 3]
# vector shape: (3,)
#
# Matriz:
# [[1 2]
#  [3 4]]
# matriz shape: (2, 2)

# %%
t = np.linspace(0,40,1000)

# %%
d_r = 2.5 * t

# %%
d_s = 3 * (t-5)

# %%
fig, ax = plt.subplots()
plt.title('El Ladron de Bancos Atrapado')
plt.xlabel('Tiempo (en minutos)')
ax.set_xlim([0, 40])
ax.set_ylim([0,100])
ax.plot(t,d_r, c= 'green')
ax.plot(t,d_s, c= 'brown')
plt.axvline(x=30, color='purple', linestyle='--')
_ = plt.axhline(y=75, color='purple', linestyle='--')

# %% [markdown]
# ### Escalares en PyTorch
#
# * PyTorch y TensorFlow son las dos librerías de *diferenciación automática* más populares en Python, a su vez el lenguaje de programación más popular en ML.
# * Los tensores de PyTorch están diseñados para ser pitónicos, es decir, para sentirse y comportarse como las matrices de NumPy.
# * La ventaja de los tensores de PyTorch respecto a los arrays de NumPy es que se pueden usar fácilmente para operaciones en la GPU.
# * La documentación sobre los tensores de PyTorch, incluyendo los tipos de datos disponibles, está [aquí](https://pytorch.org/docs/stable/tensors.html).

# %%
import torch

# %%
x_pt = torch.tensor(25)
x_pt
# Out:
# tensor(25)

# %%
x_pt.shape
# Out:
# torch.Size([])

# %% [markdown]
# # Escalares en TensorFlow (versión 2.0 o posterior)
#
# En **TensorFlow 2.x**, un **escalar** es un **tensor de rango 0**, es decir, un tensor sin dimensiones (`shape = []`).
#
# Los escalares (y tensores en general) pueden crearse de distintas formas, tal como se describe en la documentación oficial de TensorFlow:
# https://www.tensorflow.org/guide/tensor
#
# ## Creación de escalares
#
# Entre las formas más utilizadas se encuentran:
#
# - `tf.constant` – crea tensores inmutables.
# - `tf.Variable` – crea tensores mutables, comúnmente usados como parámetros entrenables.
# - `tf.convert_to_tensor` – convierte valores de Python o arrays NumPy en tensores.
# - `tf.sparse.SparseTensor` – representa tensores dispersos, generalmente usados en estructuras de mayor dimensión.
#
# En la práctica, **`tf.Variable`** es ampliamente utilizado en contextos de entrenamiento y optimización, ya que permite que el valor del tensor se actualice durante el aprendizaje.
#
# ## Comparación con otros frameworks
#
# Al igual que con TensorFlow, en **PyTorch** es posible realizar operaciones equivalentes con tensores y convertirlos fácilmente hacia y desde **arrays NumPy**.
#
# ## Tipos de datos
#
# Además, una lista completa de los tipos de datos soportados por los tensores se encuentra disponible en la documentación oficial de TensorFlow:
# https://www.tensorflow.org/api_docs/python/tf/dtypes/DType

# %%
import tensorflow as tf
# Out:
# /usr/local/lib/python3.11/site-packages/keras/src/export/tf2onnx_lib.py:8: FutureWarning: In the future `np.object` will be defined as the corresponding NumPy scalar.
#   if not hasattr(np, "object"):

# %%
x_tf = tf.Variable(25, dtype=tf.int16)

# %%
x_tf.shape
# Out:
# TensorShape([])

# %%
y_tf = tf.Variable(3, dtype=tf.int16)

# %%
x_tf.shape
# Out:
# TensorShape([])

# %%
x_tf + y_tf
# Out:
# <tf.Tensor: shape=(), dtype=int16, numpy=28>

# %%
tf_sum = tf.add(x_tf, y_tf)
tf_sum
# Out:
# <tf.Tensor: shape=(), dtype=int16, numpy=28>

# %%
tf_sum.numpy()
# Out:
# 28

# %%
type(tf_sum.numpy())
# Out:
# numpy.int16

# %%
tf_float = tf.Variable(25., dtype=tf.float16)
tf_float
# Out:
# <tf.Variable 'Variable:0' shape=() dtype=float16, numpy=25.0>

# %% [markdown]
# ### Vectores (Tensores de rango 1) en NumPy

# %%
import numpy as np

# %%
x = np.array([25,2,5])
x
# Out:
# array([25,  2,  5])

# %%
len(x)
# Out:
# 3

# %%
x.shape
# Out:
# (3,)

# %%
type(x)
# Out:
# numpy.ndarray

# %%
x[0]
# Out:
# 25

# %%
type(x[0])
# Out:
# numpy.int64

# %% [markdown]
# ### Transposición de Vectores

# %%
# Transponer una array  1-D normal no tiene ningun efecto...
x_t = x.T
x_t
# Out:
# array([25,  2,  5])

# %%
x_t.shape
# Out:
# (3,)

# %%
# ...no obstante si cuando se utiliza parentisis  anidados de tipo matriz
y = np.array([[25,2,5]])
y
# Out:
# array([[25,  2,  5]])

# %%
y.shape
# Out:
# (1, 3)

# %%
# se puede transponer una matriz de dimensión 1, lo que es equivalente matematicamente a 
y_t = y.T
y_t
# Out:
# array([[25],
#        [ 2],
#        [ 5]])

# %%
y_t.shape # Esto es un vector comjuna ya que tien 3 filas y 1 columna
# Out:
# (3, 1)

# %%
# El vector columna puede transponerse al vector fila original:
y_t.T
# Out:
# array([[25,  2,  5]])

# %%
y_t.T.shape
# Out:
# (1, 3)

# %% [markdown]
# ### Vectores nulos
#
# No tienen efecto si se suman a otro vector

# %%
z = np.zeros(3)
z
# Out:
# array([0., 0., 0.])

# %% [markdown]
# ### Vectores en PyTorch y TensorFlow

# %%
import torch

# %%
x_pt = torch.tensor([25,2,5])
x_pt
# Out:
# tensor([25,  2,  5])

# %%
import tensorflow as tf
x_tf = tf.Variable([25,2,5])
x_tf
# Out:
# <tf.Variable 'Variable:0' shape=(3,) dtype=int32, numpy=array([25,  2,  5], dtype=int32)>

# %% [markdown]
# ### Norma $L^2$

# %%
x
# Out:
# array([25,  2,  5])

# %%
(25**2 + 2**2 + 5**2)**(1/2)
# Out:
# 25.573423705088842

# %%
np.linalg.norm(x)
# Out:
# 25.573423705088842

# %% [markdown]
# De esta forma, si las unidades en este espacio vectorial tridimensional son metros, entonces el vector $x$ tiene una longitud de 25.6m

# %% [markdown]
# ### Norma $L^1$

# %%
x
# Out:
# array([25,  2,  5])

# %%
np.abs(25) + np.abs(2)  + np.abs(5)
# Out:
# 32

# %% [markdown]
# ### Norma $L^2$ al Cuadrado

# %%
x
# Out:
# array([25,  2,  5])

# %%
(25**2 + 2**2 + 5**2)
# Out:
# 654

# %%
# Mas adelante se cubrira la multiplicación tensorial
np.dot(x,x)
# Out:
# 654

# %% [markdown]
# ### Norma del Máximo

# %%
x
# Out:
# array([25,  2,  5])

# %%
np.max([np.abs(25), np.abs(2), np.abs(5)])
# Out:
# 25

# %% [markdown]
# ### Vectores Ortogonales

# %%
i = np.array([1,0])
i
# Out:
# array([1, 0])

# %%
j = np.array([0,1])
j
# Out:
# array([0, 1])

# %%
np.dot(i,j)
# Out:
# 0

# %% [markdown]
# ### Matrices (Tensores de Rango 2) en NumPy

# %%
x = np.array([[25,2], [5,26], [3,7]])
x
# Out:
# array([[25,  2],
#        [ 5, 26],
#        [ 3,  7]])

# %%
x.shape
# Out:
# (3, 2)

# %%
x.size
# Out:
# 6

# %%
# Como seleccionar la columna izquierda de la matriz x (indice 0)
x[:,0]
# Out:
# array([25,  5,  3])

# %%
# Como seleccionar la fila del medio de la matriz x (incice 1)
x[1,:]
# Out:
# array([ 5, 26])

# %%
# Otro ejemplo de slicing-by-index
x[0: 2, 0:2]
# Out:
# array([[25,  2],
#        [ 5, 26]])

# %% [markdown]
# ### Matrices en PyTorch

# %%
X_pt = torch.tensor([[25,2], [5,26], [3,7]])
X_pt
# Out:
# tensor([[25,  2],
#         [ 5, 26],
#         [ 3,  7]])

# %%
X_pt.shape #pythonico relativo a PyTorch
# Out:
# torch.Size([3, 2])

# %%
X_pt[1, :] # Python se basa en dices que empiezan en cero el algebra se basa en indice que empieza en 1
# Out:
# tensor([ 5, 26])

# %% [markdown]
# ### Matrices en TensorFlow

# %%
X_tf = tf.Variable([[25,2], [5,26], [3,7]])
X_tf
# Out:
# <tf.Variable 'Variable:0' shape=(3, 2) dtype=int32, numpy=
# array([[25,  2],
#        [ 5, 26],
#        [ 3,  7]], dtype=int32)>

# %%
tf.rank(X_tf)
# Out:
# <tf.Tensor: shape=(), dtype=int32, numpy=2>

# %%
tf.shape(X_tf)
# Out:
# <tf.Tensor: shape=(2,), dtype=int32, numpy=array([3, 2], dtype=int32)>

# %%
X_tf[1,:]
# Out:
# <tf.Tensor: shape=(2,), dtype=int32, numpy=array([ 5, 26], dtype=int32)>

# %% [markdown]
# ### Tensores de Rango Superior
#
# Como ejemplo, los tensores de rango 4 son comunes para las imágenes, donde cada dimensión corresponde a:
#
# 1. Número de imágenes en el lote de entrenamiento, por ejemplo, 32
# 2. Altura de la imagen en píxeles, por ejemplo, 28 para [MNIST digits](http://yann.lecun.com/exdb/mnist/)
# 3. Anchura de la imagen en píxeles, p. ej., 28
# 4. Número de canales de color, por ejemplo, 3 para imágenes a todo color (RGB)

# %%
images_pt = torch.zeros([32,28,28,3])

# %%
#images_pt

# %%
images_tf = tf.zeros([32,28,28,3])

# %% [markdown]
# ## Segmento 2: Operaciones con Tensores más comunes

# %%
x
# Out:
# array([[25,  2],
#        [ 5, 26],
#        [ 3,  7]])

# %%
x.T
# Out:
# array([[25,  5,  3],
#        [ 2, 26,  7]])

# %%
X_pt.T
# Out:
# tensor([[25,  5,  3],
#         [ 2, 26,  7]])

# %%
tf.transpose(X_tf)
# Out:
# <tf.Tensor: shape=(2, 3), dtype=int32, numpy=
# array([[25,  5,  3],
#        [ 2, 26,  7]], dtype=int32)>

# %% [markdown]
# ### Propiedades Aritméticas Básicas

# %% [markdown]
# Al sumar o multiplicar con escalares se aplica la operación a todos los elementos y se conserva la forma del tensor:

# %%
x
# Out:
# array([[25,  2],
#        [ 5, 26],
#        [ 3,  7]])

# %%
x*2
# Out:
# array([[50,  4],
#        [10, 52],
#        [ 6, 14]])

# %%
x+2
# Out:
# array([[27,  4],
#        [ 7, 28],
#        [ 5,  9]])

# %%
x*2+2
# Out:
# array([[52,  6],
#        [12, 54],
#        [ 8, 16]])

# %%
torch.add(torch.mul(X_pt,2),2)
# Out:
# tensor([[52,  6],
#         [12, 54],
#         [ 8, 16]])

# %%
X_tf*2+2
# Out:
# <tf.Tensor: shape=(3, 2), dtype=int32, numpy=
# array([[52,  6],
#        [12, 54],
#        [ 8, 16]], dtype=int32)>

# %%
tf.add(tf.multiply(X_tf,2),2)
# Out:
# <tf.Tensor: shape=(3, 2), dtype=int32, numpy=
# array([[52,  6],
#        [12, 54],
#        [ 8, 16]], dtype=int32)>

# %% [markdown]
# Si dos tensores tienen el mismo tamaño, las operaciones se suelen aplicar por defecto de forma elemental. No se trata de **multiplicación de matrices**, que veremos más adelante, sino que se denomina **producto de Hadamard** o simplemente **producto elemento a elemento**.
#
# La notación matemática es $A \odot X$.

# %%
x
# Out:
# array([[25,  2],
#        [ 5, 26],
#        [ 3,  7]])

# %%
A = x+2
A
# Out:
# array([[27,  4],
#        [ 7, 28],
#        [ 5,  9]])

# %%
A + x
# Out:
# array([[52,  6],
#        [12, 54],
#        [ 8, 16]])

# %%
A*x
# Out:
# array([[675,   8],
#        [ 35, 728],
#        [ 15,  63]])

# %%
A_pt = X_pt +2

# %%
A_pt + X_pt
# Out:
# tensor([[52,  6],
#         [12, 54],
#         [ 8, 16]])

# %%
A_tf = X_tf +2

# %%
A_tf + X_tf
# Out:
# <tf.Tensor: shape=(3, 2), dtype=int32, numpy=
# array([[52,  6],
#        [12, 54],
#        [ 8, 16]], dtype=int32)>

# %%
A_tf * X_tf
# Out:
# <tf.Tensor: shape=(3, 2), dtype=int32, numpy=
# array([[675,   8],
#        [ 35, 728],
#        [ 15,  63]], dtype=int32)>

# %% [markdown]
# ### Reducción

# %% [markdown]
# Calcular la suma de todos los elementos de un tensor es una operación habitual. Por ejemplo:
#
# * Para un vector ***x*** de longitud *n*, calculamos $\sum_{i=1}^{n} x_i$.
# * Para la matriz ***X*** con *m* por *n* dimensiones, calculamos $\sum_{i=1}^{m} \sum_{j=1}^{n} X_{i,j}$

# %%
x
# Out:
# array([[25,  2],
#        [ 5, 26],
#        [ 3,  7]])

# %%
x.sum()
# Out:
# 68

# %%
torch.sum(X_pt)
# Out:
# tensor(68)

# %%
tf.reduce_sum(X_tf)
# Out:
# <tf.Tensor: shape=(), dtype=int32, numpy=68>

# %%
# Tambien puede sumarse a lo largo de un eje especifico
x.sum(axis=0) #sumar sobre todas las filas
# Out:
# array([33, 35])

# %%
x.sum(axis=1) #sumar sobre todas las columnas
# Out:
# array([27, 31, 10])

# %%
torch.sum(X_pt, 0)
# Out:
# tensor([33, 35])

# %%
tf.reduce_sum(X_tf,1)
# Out:
# <tf.Tensor: shape=(3,), dtype=int32, numpy=array([27, 31, 10], dtype=int32)>

# %% [markdown]
# Pueden aplicarse muchas otras operaciones con reducción a lo largo de todos los ejes o de una selección de ellos, p. ej:
#
# * máximo
# * mínimo
# * media
# * producto
#
# Puedes buscarlas en los documentos de la biblioteca si alguna vez las necesitas.

# %% [markdown]
# ### El Producto Escalar

# %% [markdown]
# Si tenemos dos vectores (digamos, ***x*** y ***y***) con la misma longitud *n*, podemos calcular el producto punto entre ellos. Esto se anota de varias maneras diferentes, incluyendo las siguientes:
#
# * $x \cdot y$
# * $x^Ty$
# * $\langle x,y \rangle$.
#
# Independientemente de la notación que utilices (yo prefiero la primera), el cálculo es el mismo; calculamos los productos de una manera elemento a elemento y luego sumamos reductivamente a través de los productos a un valor escalar. Es decir, $x \cdot y = \sum_{i=1}^{n} x_i y_i$.
#
# El producto punto es omnipresente en el aprendizaje profundo: Se realiza en cada neurona artificial de una red neuronal profunda, que puede estar formada por millones (u órdenes de magnitud superiores) de estas neuronas.

# %%
x
# Out:
# array([[25,  2],
#        [ 5, 26],
#        [ 3,  7]])

# %%
y = np.array([0,1,2])
y
# Out:
# array([0, 1, 2])

# %%
25*0 + 2*1+ 5*2
# Out:
# 12

# %%
np.dot(x,y)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[99], line 1
# ----> 1 np.dot(x,y)
#
# ValueError: shapes (3,2) and (3,) not aligned: 2 (dim 1) != 3 (dim 0)

# %%
x_pt
# Out:
# tensor([25,  2,  5])

# %%
y_pt = torch.tensor([0,1,2])
y_pt
# Out:
# tensor([0, 1, 2])

# %%
np.dot(x_pt, y_pt)
# Out:
# 12

# %%
torch.dot(torch.tensor([25, 2, 5.]), torch.tensor([0, 1, 2.]))
# Out:
# tensor(12.)

# %%
x_tf
# Out:
# <tf.Variable 'Variable:0' shape=(3,) dtype=int32, numpy=array([25,  2,  5], dtype=int32)>

# %%
y_tf = tf.Variable([0,1,2])
y_tf
# Out:
# <tf.Variable 'Variable:0' shape=(3,) dtype=int32, numpy=array([0, 1, 2], dtype=int32)>

# %%
tf.reduce_sum(tf.multiply(x_tf, y_tf))
# Out:
# <tf.Tensor: shape=(), dtype=int32, numpy=12>

# %% [markdown]
# ### Resolución de Sistemas Lineales

# %% [markdown]
# En el ejemplo de **Sustitución**, las dos ecuaciones del sistema son:
# $$ y = 3x $$
# $$ -5x + 2y = 2 $$
#
# La segunda ecuación puede reordenarse para aislar $y$:
# $$ 2y = 2 + 5x $$
# $$ y = \frac{2 + 5x}{2} = 1 + \frac{5x}{2} $$

# %%
x = np.linspace(-10, 10, 1000) # inicio, final, n puntos

# %%
y1 = 3 * x

# %%
y2 = 1 + (5*x)/2

# %%
fig, ax = plt.subplots()
plt.xlabel('x')
plt.ylabel('y')
ax.set_xlim([0, 3])
ax.set_ylim([0, 8])
ax.plot(x, y1, c='green')
ax.plot(x, y2, c='brown')
plt.axvline(x=2, color='purple', linestyle='--')
_ = plt.axhline(y=6, color='purple', linestyle='--')

# %% [markdown]
# En el ejemplo de **Eliminación**, las dos ecuaciones del sistema son:
# $$ 2x - 3y = 15 $$
# $$ 4x + 10y = 14 $$
#
# Ambas ecuaciones pueden reordenarse para aislar $y$. A partir de la primera ecuación:
# $$ -3y = 15 - 2x $$
# $$ y = \frac{15 - 2x}{-3} = -5 + \frac{2x}{3} $$
#
# Si operamos con la segunda ecuación:
# $$ 4x + 10y = 14 $$
# $$ 2x + 5y = 7 $$
# $$ 5y = 7 - 2x $$
# $$ y = \frac{7 - 2x}{5} $$

# %%
y1= -5 + (2*x)/3

# %%
y2 = (7-2*x)/5

# %%
fig, ax = plt.subplots()
plt.xlabel('x')
plt.ylabel('y')

# Añadimos los ejes x e y:
plt.axvline(x=0, color='lightgray')
plt.axhline(y=0, color='lightgray')

ax.set_xlim([-2, 10])
ax.set_ylim([-6, 4])
ax.plot(x, y1, c='green')
ax.plot(x, y2, c='brown')
plt.axvline(x=6, color='purple', linestyle='--')
_ = plt.axhline(y=-1, color='purple', linestyle='--')

# %% [markdown]
# ## Segmento 3: Propiedades de las Matrices

# %%
import numpy as np
import torch
import tensorflow as tf

# %% [markdown]
# ### La Norma de Frobenius

# %%
X = np.array([[1, 2], [3, 4]])
X
# Out:
# array([[1, 2],
#        [3, 4]])

# %%
(1**2 + 2**2 + 3**2 + 4**2)**(1/2)
# Out:
# 5.477225575051661

# %%
X_pt = torch.tensor([[1, 2], [3, 4.]]) # torch.norm() solamente soporta floats

# %%
torch.norm(X_pt)
# Out:
# tensor(5.4772)

# %%
X_tf = tf.Variable([[1, 2], [3, 4.]]) # tf.norm() solamente soporta floats

# %%
tf.norm(X_tf)
# Out:
# <tf.Tensor: shape=(), dtype=float32, numpy=5.4772257804870605>

# %% [markdown]
# ### Multiplicación de Matrices (por un Vector)

# %%
A = np.array([[3,4],[5,6],[7,8]])
A
# Out:
# array([[3, 4],
#        [5, 6],
#        [7, 8]])

# %%
b = np.array([1,2])
b
# Out:
# array([1, 2])

# %%
np.dot(A,b)
# Out:
# array([11, 17, 23])

# %%
A_pt = torch.tensor([[3,4],[5,6],[7,8]])
A_pt
# Out:
# tensor([[3, 4],
#         [5, 6],
#         [7, 8]])

# %%
b_pt = torch.tensor([1,2])
b_pt
# Out:
# tensor([1, 2])

# %%
torch.matmul(A_pt, b_pt)
# Out:
# tensor([11, 17, 23])

# %%
A_tf = tf.Variable([[3,4],[5,6], [7,8]])
A_tf
# Out:
# <tf.Variable 'Variable:0' shape=(3, 2) dtype=int32, numpy=
# array([[3, 4],
#        [5, 6],
#        [7, 8]], dtype=int32)>

# %%
bt_tf = tf.Variable([1,2])
bt_tf
# Out:
# <tf.Variable 'Variable:0' shape=(2,) dtype=int32, numpy=array([1, 2], dtype=int32)>

# %%
tf.linalg.matvec(A_tf, bt_tf)
# Out:
# <tf.Tensor: shape=(3,), dtype=int32, numpy=array([11, 17, 23], dtype=int32)>

# %% [markdown]
# ### Multiplicación de Matrices (con Dos Matrices)
